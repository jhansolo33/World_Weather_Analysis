# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations

lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list

coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 731

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=745b7d316d5810baaa50cbf92fbec4f9'

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]['description']
        city_country = city_weather["sys"]["country"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')    
        city_data_df = pd.DataFrame(city_data)
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc,
                          "Country": city_country,
                          "Date": city_date})
        
        
        
        
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | kargil
# Processing Record 5 of Set 1 | vostok
# Processing Record 6 of Set 1 | sinnamary
# Processing Record 7 of Set 1 | bredasdorp
# Processing Record 8 of Set 1 | gushikawa
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | gayeri
# Processing Record 11 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 1 | saint george
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | mahebourg
# Processing Record 15 of Set 1 | hermanus
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | hithadhoo
# Processing Record 18 of Set 1 | cape town
# Processing Record 19 of Set 1 | vardo
# Processing Record 20 of Set 1 | revelstoke
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | kassala
# Processing Record 24 of Set 1 | half moon bay
# Processing Record 25 of Set 1 | maragogi
# Processing Record 26 of Set 1 | zabaykalsk
# Processing Record 27 of Set 1 | salalah
# Processing Record 28 of Set 1 | pointe-noire
# Processing Record 29 of Set 1 | banda aceh
# Processing Record 30 of Set 1 | svetlaya
# Processing Record 31 of Set 1 | saint-pierre
# Processing Record 32 of Set 1 | port alfred
# Processing Record 33 of Set 1 | dighwara
# Processing Record 34 of Set 1 | taseyevo
# Processing Record 35 of Set 1 | nichinan
# Processing Record 36 of Set 1 | zeya
# Processing Record 37 of Set 1 | hawalli
# Processing Record 38 of Set 1 | carnarvon
# Processing Record 39 of Set 1 | ilulissat
# Processing Record 40 of Set 1 | qaanaaq
# Processing Record 41 of Set 1 | sur
# Processing Record 42 of Set 1 | bathsheba
# Processing Record 43 of Set 1 | norman wells
# Processing Record 44 of Set 1 | accra
# Processing Record 45 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 1 | sitka
# Processing Record 47 of Set 1 | bacuit
# City not found. Skipping...
# Processing Record 48 of Set 1 | cidreira
# Processing Record 49 of Set 1 | bluff
# Processing Record 50 of Set 1 | avarua
# Processing Record 1 of Set 2 | vaini
# Processing Record 2 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 3 of Set 2 | butaritari
# Processing Record 4 of Set 2 | ribeira grande
# Processing Record 5 of Set 2 | mogadishu
# Processing Record 6 of Set 2 | port elizabeth
# Processing Record 7 of Set 2 | cap malheureux
# Processing Record 8 of Set 2 | hobyo
# Processing Record 9 of Set 2 | aksu
# Processing Record 10 of Set 2 | kruisfontein
# Processing Record 11 of Set 2 | paclolo
# Processing Record 12 of Set 2 | touros
# Processing Record 13 of Set 2 | benguela
# Processing Record 14 of Set 2 | bambous virieux
# Processing Record 15 of Set 2 | seoul
# Processing Record 16 of Set 2 | kabare
# Processing Record 17 of Set 2 | natal
# Processing Record 18 of Set 2 | thompson
# Processing Record 19 of Set 2 | puerto ayora
# Processing Record 20 of Set 2 | yellowknife
# Processing Record 21 of Set 2 | georgetown
# Processing Record 22 of Set 2 | rivadavia
# Processing Record 23 of Set 2 | iqaluit
# Processing Record 24 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 25 of Set 2 | gat
# Processing Record 26 of Set 2 | sampit
# Processing Record 27 of Set 2 | mar del plata
# Processing Record 28 of Set 2 | sao joao da barra
# Processing Record 29 of Set 2 | codrington
# Processing Record 30 of Set 2 | tiksi
# Processing Record 31 of Set 2 | saldanha
# Processing Record 32 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 2 | east london
# Processing Record 34 of Set 2 | foix
# Processing Record 35 of Set 2 | barrow
# Processing Record 36 of Set 2 | salinas
# Processing Record 37 of Set 2 | clyde river
# Processing Record 38 of Set 2 | hilo
# Processing Record 39 of Set 2 | arraial do cabo
# Processing Record 40 of Set 2 | ishigaki
# Processing Record 41 of Set 2 | brae
# Processing Record 42 of Set 2 | cayenne
# Processing Record 43 of Set 2 | port hedland
# Processing Record 44 of Set 2 | aseri
# Processing Record 45 of Set 2 | saint-augustin
# Processing Record 46 of Set 2 | makubetsu
# Processing Record 47 of Set 2 | hobart
# Processing Record 48 of Set 2 | castro
# Processing Record 49 of Set 2 | ruwi
# Processing Record 50 of Set 2 | goure
# Processing Record 1 of Set 3 | atar
# Processing Record 2 of Set 3 | port hardy
# Processing Record 3 of Set 3 | okha
# Processing Record 4 of Set 3 | upernavik
# Processing Record 5 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 3 | khatanga
# Processing Record 9 of Set 3 | nikolskoye
# Processing Record 10 of Set 3 | longyearbyen
# Processing Record 11 of Set 3 | falealupo
# City not found. Skipping...
# Processing Record 12 of Set 3 | dunedin
# Processing Record 13 of Set 3 | lasa
# Processing Record 14 of Set 3 | lapy
# Processing Record 15 of Set 3 | vao
# Processing Record 16 of Set 3 | muros
# Processing Record 17 of Set 3 | sorland
# Processing Record 18 of Set 3 | turukhansk
# Processing Record 19 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 3 | pochutla
# Processing Record 21 of Set 3 | tuatapere
# Processing Record 22 of Set 3 | asmar
# Processing Record 23 of Set 3 | ust-tsilma
# Processing Record 24 of Set 3 | geraldton
# Processing Record 25 of Set 3 | fairbanks
# Processing Record 26 of Set 3 | galiwinku
# City not found. Skipping...
# Processing Record 27 of Set 3 | new norfolk
# Processing Record 28 of Set 3 | evans
# Processing Record 29 of Set 3 | honningsvag
# Processing Record 30 of Set 3 | saint anthony
# Processing Record 31 of Set 3 | yuancheng
# Processing Record 32 of Set 3 | chengmai
# City not found. Skipping...
# Processing Record 33 of Set 3 | souillac
# Processing Record 34 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 3 | lebu
# Processing Record 36 of Set 3 | mount isa
# Processing Record 37 of Set 3 | dakar
# Processing Record 38 of Set 3 | igrim
# Processing Record 39 of Set 3 | teluk nibung
# Processing Record 40 of Set 3 | taltal
# Processing Record 41 of Set 3 | chokurdakh
# Processing Record 42 of Set 3 | waingapu
# Processing Record 43 of Set 3 | kodiak
# Processing Record 44 of Set 3 | peniche
# Processing Record 45 of Set 3 | kununurra
# Processing Record 46 of Set 3 | tsumeb
# Processing Record 47 of Set 3 | sept-iles
# Processing Record 48 of Set 3 | curup
# Processing Record 49 of Set 3 | fort nelson
# Processing Record 50 of Set 3 | anchorage
# Processing Record 1 of Set 4 | birjand
# Processing Record 2 of Set 4 | alofi
# Processing Record 3 of Set 4 | haapu
# City not found. Skipping...
# Processing Record 4 of Set 4 | tilichiki
# Processing Record 5 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 6 of Set 4 | katangli
# Processing Record 7 of Set 4 | mgandu
# Processing Record 8 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 4 | lompoc
# Processing Record 10 of Set 4 | ahuimanu
# Processing Record 11 of Set 4 | olafsvik
# Processing Record 12 of Set 4 | stornoway
# Processing Record 13 of Set 4 | dikson
# Processing Record 14 of Set 4 | harper
# Processing Record 15 of Set 4 | pevek
# Processing Record 16 of Set 4 | pinega
# Processing Record 17 of Set 4 | tabou
# Processing Record 18 of Set 4 | san cristobal
# Processing Record 19 of Set 4 | tasiilaq
# Processing Record 20 of Set 4 | hamilton
# Processing Record 21 of Set 4 | rio gallegos
# Processing Record 22 of Set 4 | torbay
# Processing Record 23 of Set 4 | sembe
# Processing Record 24 of Set 4 | booue
# Processing Record 25 of Set 4 | kahului
# Processing Record 26 of Set 4 | namatanai
# Processing Record 27 of Set 4 | udachnyy
# Processing Record 28 of Set 4 | evensk
# Processing Record 29 of Set 4 | severo-kurilsk
# Processing Record 30 of Set 4 | bandarbeyla
# Processing Record 31 of Set 4 | pisco
# Processing Record 32 of Set 4 | inta
# Processing Record 33 of Set 4 | ostrovnoy
# Processing Record 34 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 35 of Set 4 | okato
# Processing Record 36 of Set 4 | coquimbo
# Processing Record 37 of Set 4 | sorong
# Processing Record 38 of Set 4 | arlit
# Processing Record 39 of Set 4 | vestmanna
# Processing Record 40 of Set 4 | ponta do sol
# Processing Record 41 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 4 | puro
# Processing Record 43 of Set 4 | guerrero negro
# Processing Record 44 of Set 4 | coos bay
# Processing Record 45 of Set 4 | ondorhaan
# City not found. Skipping...
# Processing Record 46 of Set 4 | saskylakh
# Processing Record 47 of Set 4 | mayumba
# Processing Record 48 of Set 4 | puerto escondido
# Processing Record 49 of Set 4 | byron bay
# Processing Record 50 of Set 4 | togur
# Processing Record 1 of Set 5 | ancud
# Processing Record 2 of Set 5 | iranshahr
# Processing Record 3 of Set 5 | munirabad
# Processing Record 4 of Set 5 | vila franca do campo
# Processing Record 5 of Set 5 | san patricio
# Processing Record 6 of Set 5 | yumen
# Processing Record 7 of Set 5 | sao filipe
# Processing Record 8 of Set 5 | chico
# Processing Record 9 of Set 5 | porto novo
# Processing Record 10 of Set 5 | airai
# Processing Record 11 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 5 | victoria
# Processing Record 13 of Set 5 | ugoofaaru
# Processing Record 14 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 15 of Set 5 | maghama
# City not found. Skipping...
# Processing Record 16 of Set 5 | naliya
# Processing Record 17 of Set 5 | samarai
# Processing Record 18 of Set 5 | necochea
# Processing Record 19 of Set 5 | caravelas
# Processing Record 20 of Set 5 | atuona
# Processing Record 21 of Set 5 | merauke
# Processing Record 22 of Set 5 | pacific grove
# Processing Record 23 of Set 5 | opuwo
# Processing Record 24 of Set 5 | vila velha
# Processing Record 25 of Set 5 | itarema
# Processing Record 26 of Set 5 | tuktoyaktuk
# Processing Record 27 of Set 5 | chicama
# Processing Record 28 of Set 5 | bacungan
# Processing Record 29 of Set 5 | turinsk
# Processing Record 30 of Set 5 | ghanzi
# Processing Record 31 of Set 5 | jinka
# Processing Record 32 of Set 5 | leningradskiy
# Processing Record 33 of Set 5 | gore
# Processing Record 34 of Set 5 | sakakah
# Processing Record 35 of Set 5 | isla mujeres
# Processing Record 36 of Set 5 | zhigansk
# Processing Record 37 of Set 5 | cherskiy
# Processing Record 38 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 5 | severnyy
# Processing Record 40 of Set 5 | thinadhoo
# Processing Record 41 of Set 5 | freeport
# Processing Record 42 of Set 5 | nemuro
# Processing Record 43 of Set 5 | kieta
# Processing Record 44 of Set 5 | mecca
# Processing Record 45 of Set 5 | sabya
# Processing Record 46 of Set 5 | san quintin
# Processing Record 47 of Set 5 | havoysund
# Processing Record 48 of Set 5 | iskilip
# Processing Record 49 of Set 5 | cumaribo
# City not found. Skipping...
# Processing Record 50 of Set 5 | kasra
# City not found. Skipping...
# Processing Record 1 of Set 6 | brenham
# Processing Record 2 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 6 | bethel
# Processing Record 4 of Set 6 | luderitz
# Processing Record 5 of Set 6 | xuddur
# Processing Record 6 of Set 6 | minna
# Processing Record 7 of Set 6 | linjiang
# Processing Record 8 of Set 6 | raduzhnyy
# Processing Record 9 of Set 6 | ambulu
# Processing Record 10 of Set 6 | homer
# Processing Record 11 of Set 6 | luanda
# Processing Record 12 of Set 6 | hovd
# Processing Record 13 of Set 6 | puerto del rosario
# Processing Record 14 of Set 6 | khandbari
# Processing Record 15 of Set 6 | saint-philippe
# Processing Record 16 of Set 6 | port-cartier
# Processing Record 17 of Set 6 | lagoa
# Processing Record 18 of Set 6 | flin flon
# Processing Record 19 of Set 6 | constitucion
# Processing Record 20 of Set 6 | padang
# Processing Record 21 of Set 6 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 22 of Set 6 | valparaiso
# Processing Record 23 of Set 6 | boa vista
# Processing Record 24 of Set 6 | chinna salem
# Processing Record 25 of Set 6 | bairiki
# Processing Record 26 of Set 6 | husavik
# Processing Record 27 of Set 6 | college
# Processing Record 28 of Set 6 | san lawrenz
# Processing Record 29 of Set 6 | yialos
# City not found. Skipping...
# Processing Record 30 of Set 6 | ucluelet
# Processing Record 31 of Set 6 | beringovskiy
# Processing Record 32 of Set 6 | lavrentiya
# Processing Record 33 of Set 6 | hasaki
# Processing Record 34 of Set 6 | filingue
# Processing Record 35 of Set 6 | bengkulu
# Processing Record 36 of Set 6 | svetlyy
# Processing Record 37 of Set 6 | kangaatsiaq
# Processing Record 38 of Set 6 | the valley
# Processing Record 39 of Set 6 | nome
# Processing Record 40 of Set 6 | ponta delgada
# Processing Record 41 of Set 6 | khor
# Processing Record 42 of Set 6 | phangnga
# Processing Record 43 of Set 6 | chuy
# Processing Record 44 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 45 of Set 6 | egvekinot
# Processing Record 46 of Set 6 | narsaq
# Processing Record 47 of Set 6 | oskarshamn
# Processing Record 48 of Set 6 | sioux lookout
# Processing Record 49 of Set 6 | waipawa
# Processing Record 50 of Set 6 | fereydunshahr
# Processing Record 1 of Set 7 | samarinda
# Processing Record 2 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 7 | camacha
# Processing Record 4 of Set 7 | wellington
# Processing Record 5 of Set 7 | nanortalik
# Processing Record 6 of Set 7 | wajima
# Processing Record 7 of Set 7 | champerico
# Processing Record 8 of Set 7 | bajram curri
# Processing Record 9 of Set 7 | karoi
# Processing Record 10 of Set 7 | abhayapuri
# Processing Record 11 of Set 7 | puerto leguizamo
# Processing Record 12 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 13 of Set 7 | privolnyy
# Processing Record 14 of Set 7 | kracheh
# City not found. Skipping...
# Processing Record 15 of Set 7 | sucua
# Processing Record 16 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 17 of Set 7 | port blair
# Processing Record 18 of Set 7 | la baneza
# Processing Record 19 of Set 7 | fortuna
# Processing Record 20 of Set 7 | ninghai
# Processing Record 21 of Set 7 | saint-joseph
# Processing Record 22 of Set 7 | korla
# Processing Record 23 of Set 7 | mier
# Processing Record 24 of Set 7 | kutum
# Processing Record 25 of Set 7 | jadu
# Processing Record 26 of Set 7 | provideniya
# Processing Record 27 of Set 7 | bekasi
# Processing Record 28 of Set 7 | port shepstone
# Processing Record 29 of Set 7 | sao felix do xingu
# Processing Record 30 of Set 7 | inirida
# Processing Record 31 of Set 7 | kaitangata
# Processing Record 32 of Set 7 | bayshore gardens
# Processing Record 33 of Set 7 | adrar
# Processing Record 34 of Set 7 | bubaque
# Processing Record 35 of Set 7 | nador
# Processing Record 36 of Set 7 | provins
# Processing Record 37 of Set 7 | diamantino
# Processing Record 38 of Set 7 | galveston
# Processing Record 39 of Set 7 | klaksvik
# Processing Record 40 of Set 7 | kloulklubed
# Processing Record 41 of Set 7 | plouzane
# Processing Record 42 of Set 7 | akhmim
# Processing Record 43 of Set 7 | walvis bay
# Processing Record 44 of Set 7 | biak
# Processing Record 45 of Set 7 | guanica
# Processing Record 46 of Set 7 | gamba
# Processing Record 47 of Set 7 | sibolga
# Processing Record 48 of Set 7 | pitimbu
# Processing Record 49 of Set 7 | santiago del estero
# Processing Record 50 of Set 7 | subang
# Processing Record 1 of Set 8 | axim
# Processing Record 2 of Set 8 | fomboni
# Processing Record 3 of Set 8 | belyy yar
# Processing Record 4 of Set 8 | praia da vitoria
# Processing Record 5 of Set 8 | quatre cocos
# Processing Record 6 of Set 8 | geresk
# City not found. Skipping...
# Processing Record 7 of Set 8 | ciudad bolivar
# Processing Record 8 of Set 8 | sargatskoye
# Processing Record 9 of Set 8 | chumikan
# Processing Record 10 of Set 8 | manta
# Processing Record 11 of Set 8 | hvammstangi
# City not found. Skipping...
# Processing Record 12 of Set 8 | poole
# Processing Record 13 of Set 8 | caloundra
# Processing Record 14 of Set 8 | hurricane
# Processing Record 15 of Set 8 | guadalupe y calvo
# Processing Record 16 of Set 8 | la ferte-bernard
# Processing Record 17 of Set 8 | denpasar
# Processing Record 18 of Set 8 | margate
# Processing Record 19 of Set 8 | tazmalt
# Processing Record 20 of Set 8 | hervey bay
# Processing Record 21 of Set 8 | kampot
# Processing Record 22 of Set 8 | muisne
# Processing Record 23 of Set 8 | iberia
# Processing Record 24 of Set 8 | harwich
# Processing Record 25 of Set 8 | santa catarina de tepehuanes
# Processing Record 26 of Set 8 | faanui
# Processing Record 27 of Set 8 | lata
# Processing Record 28 of Set 8 | vanavara
# Processing Record 29 of Set 8 | los llanos de aridane
# Processing Record 30 of Set 8 | bandar
# Processing Record 31 of Set 8 | skage
# City not found. Skipping...
# Processing Record 32 of Set 8 | los algarrobos
# Processing Record 33 of Set 8 | marsa matruh
# Processing Record 34 of Set 8 | leh
# Processing Record 35 of Set 8 | kisangani
# Processing Record 36 of Set 8 | jonuta
# Processing Record 37 of Set 8 | pangnirtung
# Processing Record 38 of Set 8 | kula
# Processing Record 39 of Set 8 | guarapari
# Processing Record 40 of Set 8 | bealanana
# Processing Record 41 of Set 8 | cabo san lucas
# Processing Record 42 of Set 8 | sinjai
# Processing Record 43 of Set 8 | yertsevo
# Processing Record 44 of Set 8 | pokhara
# Processing Record 45 of Set 8 | tuy hoa
# Processing Record 46 of Set 8 | vawkavysk
# Processing Record 47 of Set 8 | imabari
# City not found. Skipping...
# Processing Record 48 of Set 8 | meulaboh
# Processing Record 49 of Set 8 | xingyi
# Processing Record 50 of Set 8 | namtsy
# Processing Record 1 of Set 9 | zhezkazgan
# Processing Record 2 of Set 9 | caohe
# Processing Record 3 of Set 9 | westport
# Processing Record 4 of Set 9 | along
# Processing Record 5 of Set 9 | verkhoyansk
# Processing Record 6 of Set 9 | san rafael
# Processing Record 7 of Set 9 | pires do rio
# Processing Record 8 of Set 9 | yar-sale
# Processing Record 9 of Set 9 | srednekolymsk
# Processing Record 10 of Set 9 | fenoarivo
# Processing Record 11 of Set 9 | whitehorse
# Processing Record 12 of Set 9 | kavieng
# Processing Record 13 of Set 9 | muzhi
# Processing Record 14 of Set 9 | siguiri
# Processing Record 15 of Set 9 | port pirie
# Processing Record 16 of Set 9 | akyab
# Processing Record 17 of Set 9 | nyurba
# Processing Record 18 of Set 9 | pasni
# Processing Record 19 of Set 9 | nang rong
# Processing Record 20 of Set 9 | havre-saint-pierre
# Processing Record 21 of Set 9 | anadyr
# Processing Record 22 of Set 9 | lujan
# Processing Record 23 of Set 9 | isangel
# Processing Record 24 of Set 9 | xining
# Processing Record 25 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 26 of Set 9 | ejura
# Processing Record 27 of Set 9 | bilibino
# Processing Record 28 of Set 9 | general roca
# Processing Record 29 of Set 9 | cimitarra
# Processing Record 30 of Set 9 | suntar
# Processing Record 31 of Set 9 | palafrugell
# Processing Record 32 of Set 9 | west odessa
# Processing Record 33 of Set 9 | chirongui
# Processing Record 34 of Set 9 | asau
# Processing Record 35 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 9 | takoradi
# Processing Record 37 of Set 9 | maloshuyka
# City not found. Skipping...
# Processing Record 38 of Set 9 | pompeu
# Processing Record 39 of Set 9 | parfenyevo
# Processing Record 40 of Set 9 | wilmington
# Processing Record 41 of Set 9 | west des moines
# Processing Record 42 of Set 9 | ambon
# Processing Record 43 of Set 9 | mendahara
# City not found. Skipping...
# Processing Record 44 of Set 9 | borken
# Processing Record 45 of Set 9 | beira
# Processing Record 46 of Set 9 | popondetta
# Processing Record 47 of Set 9 | tura
# Processing Record 48 of Set 9 | flinders
# Processing Record 49 of Set 9 | scarborough
# Processing Record 50 of Set 9 | dzhebariki-khaya
# Processing Record 1 of Set 10 | zlitan
# Processing Record 2 of Set 10 | lincoln
# Processing Record 3 of Set 10 | mombaca
# Processing Record 4 of Set 10 | cockburn town
# Processing Record 5 of Set 10 | patos de minas
# Processing Record 6 of Set 10 | phumi samraong
# City not found. Skipping...
# Processing Record 7 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 8 of Set 10 | kidal
# Processing Record 9 of Set 10 | ammon
# Processing Record 10 of Set 10 | kavaratti
# Processing Record 11 of Set 10 | lhokseumawe
# Processing Record 12 of Set 10 | bulungu
# Processing Record 13 of Set 10 | cabedelo
# Processing Record 14 of Set 10 | pec
# Processing Record 15 of Set 10 | rawson
# Processing Record 16 of Set 10 | flagstaff
# Processing Record 17 of Set 10 | xiaoweizhai
# Processing Record 18 of Set 10 | hambantota
# Processing Record 19 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 10 | zheleznogorsk-ilimskiy
# Processing Record 21 of Set 10 | atasu
# Processing Record 22 of Set 10 | barcarena
# Processing Record 23 of Set 10 | vanimo
# Processing Record 24 of Set 10 | jarjis
# City not found. Skipping...
# Processing Record 25 of Set 10 | tessalit
# Processing Record 26 of Set 10 | beaumont
# Processing Record 27 of Set 10 | roma
# Processing Record 28 of Set 10 | ahipara
# Processing Record 29 of Set 10 | shache
# Processing Record 30 of Set 10 | paita
# Processing Record 31 of Set 10 | bilma
# Processing Record 32 of Set 10 | karratha
# Processing Record 33 of Set 10 | nyandoma
# Processing Record 34 of Set 10 | acarau
# Processing Record 35 of Set 10 | lubango
# Processing Record 36 of Set 10 | zhaotong
# Processing Record 37 of Set 10 | broome
# Processing Record 38 of Set 10 | gangotri
# City not found. Skipping...
# Processing Record 39 of Set 10 | grindavik
# Processing Record 40 of Set 10 | pulivendla
# Processing Record 41 of Set 10 | shu
# Processing Record 42 of Set 10 | coihaique
# Processing Record 43 of Set 10 | severnoye
# Processing Record 44 of Set 10 | inhambane
# Processing Record 45 of Set 10 | biltine
# Processing Record 46 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 47 of Set 10 | cap-aux-meules
# Processing Record 48 of Set 10 | warrington
# Processing Record 49 of Set 10 | dashitou
# Processing Record 50 of Set 10 | nokaneng

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
# city_data_df = city_data__no_date_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']]
# city_data__no_date_df
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# %%
# Display sample datacity_data_df = pd.DataFrame(city_data)

city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0            Bluff -46.6000  168.3333     56.80          few clouds        68
# 1            Metro  -5.1131  105.3067     88.48     overcast clouds        54
# 2    Pacific Grove  36.6177 -121.9166     64.08           clear sky        87
# 3     Saint George  37.1041 -113.5841     79.95           clear sky        40
# 4          Mataura -46.1927  168.8643     56.48          few clouds        56
# 5          Biltine  14.5333   20.9167     80.42    scattered clouds        61
# 6              Gao  16.6362    1.6370     85.73       broken clouds        47
# 7        Hithadhoo  -0.6000   73.0833     82.00    scattered clouds        72
# 8  Bambous Virieux -20.3428   57.7575     76.21       broken clouds        78
# 9          Rikitea -23.1203 -134.9692     73.35           clear sky        72
#
#    Cloudiness  Wind Speed Country
# 0          21        2.28      NZ
# 1          92        4.52      ID
# 2           0        4.61      US
# 3           0       10.36      US
# 4          15        2.44      NZ
# 5          27        3.36      TD
# 6          77        6.31      ML
# 7          47        7.78      MV
# 8          75       13.80      MU
# 9           3       14.23      PF

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE

# Display sample data
# YOUR CODE HERE
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Bluff      NZ -46.6000  168.3333     56.80        68          21
# 1            Metro      ID  -5.1131  105.3067     88.48        54          92
# 2    Pacific Grove      US  36.6177 -121.9166     64.08        87           0
# 3     Saint George      US  37.1041 -113.5841     79.95        40           0
# 4          Mataura      NZ -46.1927  168.8643     56.48        56          15
# 5          Biltine      TD  14.5333   20.9167     80.42        61          27
# 6              Gao      ML  16.6362    1.6370     85.73        47          77
# 7        Hithadhoo      MV  -0.6000   73.0833     82.00        72          47
# 8  Bambous Virieux      MU -20.3428   57.7575     76.21        78          75
# 9          Rikitea      PF -23.1203 -134.9692     73.35        72           3
#
#    Wind Speed Current Description
# 0        2.28          few clouds
# 1        4.52     overcast clouds
# 2        4.61           clear sky
# 3       10.36           clear sky
# 4        2.44          few clouds
# 5        3.36    scattered clouds
# 6        6.31       broken clouds
# 7        7.78    scattered clouds
# 8       13.80       broken clouds
# 9       14.23           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE

# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE
